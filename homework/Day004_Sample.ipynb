# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10996062396","type":"CreateEvent","actor":{"id":49699333,"login":"dependabot[bot]","display_login":"dependabot","gravatar_id":"","url":"https://api.github.com/users/dependabot[bot]","avatar_url":"https://avatars.githubusercontent.com/u/49699333?"},"repo":{"id":150663156,"name":"derricknoutais/sta","url":"https://api.github.com/repos/derricknoutais/sta"},"payload":{"ref":"dependabot/composer/symfony/http-foundation-4.4.1","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-03T05:28:35Z"},{"id":"10996062381","type":"PushEvent","actor":{"id":48541779,"login":"Claire1995","display_login":"Claire1995","gravatar_id":"","url":"https://api.github.com/users/Claire1995","avatar_url":"https://avatars.githubusercontent.com/u/48541779?"},"repo":{"id":224149419,"name":"Claire1995/SQLearner","url":"https://api.github.com/repos/Claire1995/SQLearner"},"payload":{"push_id":4347165998,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"653d5d2a5b777ed69b6b0e814fc7c2f90df51acb","before":"8a0533806482522d7dbd97748ec57ea6199c0790","commits":[{"sha":"653d5d2a5b777ed69b6b0e814fc7c2f90df51acb","author":{"email":"songvely17@gmail.com","name":"Clarie Song"},"message":"las","distinct":true,"url":"https://api.github.com/repos/Claire1995/SQLearner/commits/653d5d2a5b777ed69b6b0e814fc7c2f90df51acb"}]},"public":true,"created_at":"2019-12-03T05:28:35Z"},{"id":"10996062378","type":"PushEvent","actor":{"id":16422262,"login":"puneethsaladi","display_login":"puneethsaladi","gravatar_id":"","url":"https://api.github.com/users/puneethsaladi","avatar_url":"https://avatars.githubusercontent.com/u/16422262?"},"repo":{"id":224311093,"name":"puneethsaladi/speed-dating","url":"https://api.github.com/repos/puneethsaladi/speed-dating"},"payload":{"push_id":4347165996,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"a7e144d13e2d04cdb1a31483c27b7366a98b3c89","before":"3a6d7ceda5868d0bd8fa17368435ec5464d45e7f","commits":[{"sha":"a7e144d13e2d04cdb1a31483c27b7366a98b3c89","author":{"email":"puneethsaladi@gmail.com","name":"puneethsaladi"},"message":"in progress","distinct":true,"url":"https://api.github.com/repos/puneethsaladi/speed-dating/commits/a7e144d13e2d04cdb1a31483c27b7366a98b3c89"}]},"public":true,"created_at":"2019-12-03T05:28:35Z"},{"id":"10996062385","type":"CreateEvent","actor":{"id":29667925,"login":"KSamra","display_login":"KSamra","gravatar_id":"","url":"https://api.github.com/users/KSamra","avatar_url":"https://avatars.githubusercontent.com/u/29667925?"},"repo":{"id":225091050,"name":"gopojiman/Successful-Startups","url":"https://api.github.com/repos/gopojiman/Successful-Startups"},"payload":{"ref":"category-binning","ref_type":"branch","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2019-12-03T05:28:35Z"},{"id":"10996062373","type":"PushEvent","actor":{"id":55468829,"login":"rkyungah","display_login":"rkyungah","gravatar_id":"","url":"https://api.github.com/users/rkyungah","avatar_url":"https://avatars.githubusercontent.com/u/55468829?"},"repo":{"id":214170353,"name":"rkyungah/Basic.github.io","url":"https://api.github.com/repos/rkyungah/Basic.github.io"},"payload":{"push_id":4347165984,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"cf8284bdf8926176f9c4425616ffd967fd11eb10","before":"c48c464d85e79b93a221eee14b81ccf9e08762a4","commits":[{"sha":"cf8284bdf8926176f9c4425616ffd967fd11eb10","author":{"email":"55468829+rkyungah@users.noreply.github.com","name":"rkyungah"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/rkyungah/Basic.github.io/commits/cf8284bdf8926176f9c4425616ffd967fd11eb10"}]},"public":true,"created_at":"2019-12-03T05:28:35Z"},{"id":"10996062365","type":"PushEvent","actor":{"id":48289398,"login":"joko19","display_login":"joko19","gravatar_id":"","url":"https://api.github.com/users/joko19","avatar_url":"https://avatars.githubusercontent.com/u/48289398?"},"repo": ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10996062396',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 150663156,
#    'name': 'derricknoutais/sta',
#    'url': 'https://api.github.com/repos/derricknoutais/sta'},
#   'payload': {'ref': 'dependabot/composer/symfony/http-foundation-4.4.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062381',
#   'type': 'PushEvent',
#   'actor': {'id': 48541779,
#    'login': 'Claire1995',
#    'display_login': 'Claire1995',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Claire1995',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48541779?'},
#   'repo': {'id': 224149419,
#    'name': 'Claire1995/SQLearner',
#    'url': 'https://api.github.com/repos/Claire1995/SQLearner'},
#   'payload': {'push_id': 4347165998,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '653d5d2a5b777ed69b6b0e814fc7c2f90df51acb',
#    'before': '8a0533806482522d7dbd97748ec57ea6199c0790',
#    'commits': [{'sha': '653d5d2a5b777ed69b6b0e814fc7c2f90df51acb',
#      'author': {'email': 'songvely17@gmail.com', 'name': 'Clarie Song'},
#      'message': 'las',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Claire1995/SQLearner/commits/653d5d2a5b777ed69b6b0e814fc7c2f90df51acb'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062378',
#   'type': 'PushEvent',
#   'actor': {'id': 16422262,
#    'login': 'puneethsaladi',
#    'display_login': 'puneethsaladi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/puneethsaladi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16422262?'},
#   'repo': {'id': 224311093,
#    'name': 'puneethsaladi/speed-dating',
#    'url': 'https://api.github.com/repos/puneethsaladi/speed-dating'},
#   'payload': {'push_id': 4347165996,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a7e144d13e2d04cdb1a31483c27b7366a98b3c89',
#    'before': '3a6d7ceda5868d0bd8fa17368435ec5464d45e7f',
#    'commits': [{'sha': 'a7e144d13e2d04cdb1a31483c27b7366a98b3c89',
#      'author': {'email': 'puneethsaladi@gmail.com', 'name': 'puneethsaladi'},
#      'message': 'in progress',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/puneethsaladi/speed-dating/commits/a7e144d13e2d04cdb1a31483c27b7366a98b3c89'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062385',
#   'type': 'CreateEvent',
#   'actor': {'id': 29667925,
#    'login': 'KSamra',
#    'display_login': 'KSamra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KSamra',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29667925?'},
#   'repo': {'id': 225091050,
#    'name': 'gopojiman/Successful-Startups',
#    'url': 'https://api.github.com/repos/gopojiman/Successful-Startups'},
#   'payload': {'ref': 'category-binning',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062373',
#   'type': 'PushEvent',
#   'actor': {'id': 55468829,
#    'login': 'rkyungah',
#    'display_login': 'rkyungah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rkyungah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55468829?'},
#   'repo': {'id': 214170353,
#    'name': 'rkyungah/Basic.github.io',
#    'url': 'https://api.github.com/repos/rkyungah/Basic.github.io'},
#   'payload': {'push_id': 4347165984,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cf8284bdf8926176f9c4425616ffd967fd11eb10',
#    'before': 'c48c464d85e79b93a221eee14b81ccf9e08762a4',
#    'commits': [{'sha': 'cf8284bdf8926176f9c4425616ffd967fd11eb10',
#      'author': {'email': '55468829+rkyungah@users.noreply.github.com',
#       'name': 'rkyungah'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rkyungah/Basic.github.io/commits/cf8284bdf8926176f9c4425616ffd967fd11eb10'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062365',
#   'type': 'PushEvent',
#   'actor': {'id': 48289398,
#    'login': 'joko19',
#    'display_login': 'joko19',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joko19',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48289398?'},
#   'repo': {'id': 225537130,
#    'name': 'joko19/Tri',
#    'url': 'https://api.github.com/repos/joko19/Tri'},
#   'payload': {'push_id': 4347165991,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9616ae054aec2a1f435e81cb9193d68c1034f1f9',
#    'before': '006f851697dd39c96ef46cb4502e0b62880716b0',
#    'commits': [{'sha': '9616ae054aec2a1f435e81cb9193d68c1034f1f9',
#      'author': {'email': 'jokoslamet459@gmail.com', 'name': 'joko19'},
#      'message': 'change color',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/joko19/Tri/commits/9616ae054aec2a1f435e81cb9193d68c1034f1f9'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062368',
#   'type': 'PushEvent',
#   'actor': {'id': 42700729,
#    'login': 'Arif-X',
#    'display_login': 'Arif-X',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arif-X',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42700729?'},
#   'repo': {'id': 212911563,
#    'name': 'Arif-X/CRUD_Laravel',
#    'url': 'https://api.github.com/repos/Arif-X/CRUD_Laravel'},
#   'payload': {'push_id': 4347165992,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7323ac1a05f3ead6dc704846499e8537f3089df7',
#    'before': 'f05f5bcd8a988a94407f002c60bb5c56c7d4419e',
#    'commits': [{'sha': '7323ac1a05f3ead6dc704846499e8537f3089df7',
#      'author': {'email': '42700729+Arif-X@users.noreply.github.com',
#       'name': 'Ariffudin Not Responding'},
#      'message': 'Delete composer.lock',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Arif-X/CRUD_Laravel/commits/7323ac1a05f3ead6dc704846499e8537f3089df7'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062367',
#   'type': 'PushEvent',
#   'actor': {'id': 2210005,
#    'login': 'hanisathish',
#    'display_login': 'hanisathish',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hanisathish',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2210005?'},
#   'repo': {'id': 201448382,
#    'name': 'LMLokesh/dallas',
#    'url': 'https://api.github.com/repos/LMLokesh/dallas'},
#   'payload': {'push_id': 4347165990,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/Phase-1',
#    'head': '3481c60e69d542f698cdd5230574d2851b3e4abe',
#    'before': '7ff9e1151cc5b4079acf15bccd16e9841a42f433',
#    'commits': [{'sha': '3481c60e69d542f698cdd5230574d2851b3e4abe',
#      'author': {'email': 'santhosh.p@CORP.SYSTECHMNG.NET',
#       'name': 'Santhosh Krishnan'},
#      'message': 'update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LMLokesh/dallas/commits/3481c60e69d542f698cdd5230574d2851b3e4abe'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062350',
#   'type': 'WatchEvent',
#   'actor': {'id': 964743,
#    'login': 'y-jono',
#    'display_login': 'y-jono',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/y-jono',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/964743?'},
#   'repo': {'id': 187978837,
#    'name': 'KatLab-MiyazakiUniv/CameraSystem',
#    'url': 'https://api.github.com/repos/KatLab-MiyazakiUniv/CameraSystem'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z',
#   'org': {'id': 41832468,
#    'login': 'KatLab-MiyazakiUniv',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/KatLab-MiyazakiUniv',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41832468?'}},
#  {'id': '10996062348',
#   'type': 'CreateEvent',
#   'actor': {'id': 10050327,
#    'login': 'Shravan90029',
#    'display_login': 'Shravan90029',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Shravan90029',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10050327?'},
#   'repo': {'id': 224107332,
#    'name': 'Shravan90029/MAC01',
#    'url': 'https://api.github.com/repos/Shravan90029/MAC01'},
#   'payload': {'ref': 'Branch2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'mac 01 - test01',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062333',
#   'type': 'PushEvent',
#   'actor': {'id': 47833295,
#    'login': 'Silent9790',
#    'display_login': 'Silent9790',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Silent9790',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47833295?'},
#   'repo': {'id': 224369074,
#    'name': 'Silent9790/Homework2',
#    'url': 'https://api.github.com/repos/Silent9790/Homework2'},
#   'payload': {'push_id': 4347165968,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ad5cf9d0dd2066e656c519052dbc5dd19ef61354',
#    'before': '121b86d437cfba6b0e62d70c61253473d56416ad',
#    'commits': [{'sha': 'ad5cf9d0dd2066e656c519052dbc5dd19ef61354',
#      'author': {'email': 'tpedro1117@gmail.com', 'name': 'Silent9790'},
#      'message': 'Delete homework2new.html',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Silent9790/Homework2/commits/ad5cf9d0dd2066e656c519052dbc5dd19ef61354'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062330',
#   'type': 'PushEvent',
#   'actor': {'id': 8083855,
#    'login': 'varlesh',
#    'display_login': 'varlesh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/varlesh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8083855?'},
#   'repo': {'id': 129393099,
#    'name': 'PapirusDevelopmentTeam/materia-kde',
#    'url': 'https://api.github.com/repos/PapirusDevelopmentTeam/materia-kde'},
#   'payload': {'push_id': 4347165967,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b01e5964af0e035544ef7012e53d84c7fdf42012',
#    'before': '0e20ca4b3b1ad78b3ee8ee5a8f2239ec439431b3',
#    'commits': [{'sha': 'b01e5964af0e035544ef7012e53d84c7fdf42012',
#      'author': {'email': 'varlesh@gmail.com', 'name': 'Alexey Varfolomeev'},
#      'message': '[Kvantum] Fix align frame on Toolbar #53',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PapirusDevelopmentTeam/materia-kde/commits/b01e5964af0e035544ef7012e53d84c7fdf42012'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z',
#   'org': {'id': 19689649,
#    'login': 'PapirusDevelopmentTeam',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PapirusDevelopmentTeam',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19689649?'}},
#  {'id': '10996062329',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 203700918,
#    'name': 'mvpvg/rust',
#    'url': 'https://api.github.com/repos/mvpvg/rust'},
#   'payload': {'action': 'opened',
#    'number': 454,
#    'pull_request': {'url': 'https://api.github.com/repos/mvpvg/rust/pulls/454',
#     'id': 348129528,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4MTI5NTI4',
#     'html_url': 'https://github.com/mvpvg/rust/pull/454',
#     'diff_url': 'https://github.com/mvpvg/rust/pull/454.diff',
#     'patch_url': 'https://github.com/mvpvg/rust/pull/454.patch',
#     'issue_url': 'https://api.github.com/repos/mvpvg/rust/issues/454',
#     'number': 454,
#     'state': 'open',
#     'locked': False,
#     'title': '[pull] master from rust-lang:master',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See Commits and Changes for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull). Want to support this open source service? [Please star it : )](https://github.com/wei/pull)',
#     'created_at': '2019-12-03T05:28:34Z',
#     'updated_at': '2019-12-03T05:28:34Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/mvpvg/rust/pulls/454/commits',
#     'review_comments_url': 'https://api.github.com/repos/mvpvg/rust/pulls/454/comments',
#     'review_comment_url': 'https://api.github.com/repos/mvpvg/rust/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/mvpvg/rust/issues/454/comments',
#     'statuses_url': 'https://api.github.com/repos/mvpvg/rust/statuses/4787e97475de6be9487e3d9255a9c2d3c0bf9252',
#     'head': {'label': 'rust-lang:master',
#      'ref': 'master',
#      'sha': '4787e97475de6be9487e3d9255a9c2d3c0bf9252',
#      'user': {'login': 'rust-lang',
#       'id': 5430905,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU0MzA5MDU=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/5430905?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/rust-lang',
#       'html_url': 'https://github.com/rust-lang',
#       'followers_url': 'https://api.github.com/users/rust-lang/followers',
#       'following_url': 'https://api.github.com/users/rust-lang/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/rust-lang/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/rust-lang/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/rust-lang/subscriptions',
#       'organizations_url': 'https://api.github.com/users/rust-lang/orgs',
#       'repos_url': 'https://api.github.com/users/rust-lang/repos',
#       'events_url': 'https://api.github.com/users/rust-lang/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/rust-lang/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 724712,
#       'node_id': 'MDEwOlJlcG9zaXRvcnk3MjQ3MTI=',
#       'name': 'rust',
#       'full_name': 'rust-lang/rust',
#       'private': False,
#       'owner': {'login': 'rust-lang',
#        'id': 5430905,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjU0MzA5MDU=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/5430905?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/rust-lang',
#        'html_url': 'https://github.com/rust-lang',
#        'followers_url': 'https://api.github.com/users/rust-lang/followers',
#        'following_url': 'https://api.github.com/users/rust-lang/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/rust-lang/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/rust-lang/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/rust-lang/subscriptions',
#        'organizations_url': 'https://api.github.com/users/rust-lang/orgs',
#        'repos_url': 'https://api.github.com/users/rust-lang/repos',
#        'events_url': 'https://api.github.com/users/rust-lang/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/rust-lang/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/rust-lang/rust',
#       'description': 'Empowering everyone to build reliable and efficient software.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/rust-lang/rust',
#       'forks_url': 'https://api.github.com/repos/rust-lang/rust/forks',
#       'keys_url': 'https://api.github.com/repos/rust-lang/rust/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/rust-lang/rust/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/rust-lang/rust/teams',
#       'hooks_url': 'https://api.github.com/repos/rust-lang/rust/hooks',
#       'issue_events_url': 'https://api.github.com/repos/rust-lang/rust/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/rust-lang/rust/events',
#       'assignees_url': 'https://api.github.com/repos/rust-lang/rust/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/rust-lang/rust/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/rust-lang/rust/tags',
#       'blobs_url': 'https://api.github.com/repos/rust-lang/rust/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/rust-lang/rust/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/rust-lang/rust/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/rust-lang/rust/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/rust-lang/rust/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/rust-lang/rust/languages',
#       'stargazers_url': 'https://api.github.com/repos/rust-lang/rust/stargazers',
#       'contributors_url': 'https://api.github.com/repos/rust-lang/rust/contributors',
#       'subscribers_url': 'https://api.github.com/repos/rust-lang/rust/subscribers',
#       'subscription_url': 'https://api.github.com/repos/rust-lang/rust/subscription',
#       'commits_url': 'https://api.github.com/repos/rust-lang/rust/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/rust-lang/rust/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/rust-lang/rust/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/rust-lang/rust/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/rust-lang/rust/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/rust-lang/rust/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/rust-lang/rust/merges',
#       'archive_url': 'https://api.github.com/repos/rust-lang/rust/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/rust-lang/rust/downloads',
#       'issues_url': 'https://api.github.com/repos/rust-lang/rust/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/rust-lang/rust/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/rust-lang/rust/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/rust-lang/rust/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/rust-lang/rust/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/rust-lang/rust/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/rust-lang/rust/deployments',
#       'created_at': '2010-06-16T20:39:03Z',
#       'updated_at': '2019-12-03T05:19:58Z',
#       'pushed_at': '2019-12-03T05:19:57Z',
#       'git_url': 'git://github.com/rust-lang/rust.git',
#       'ssh_url': 'git@github.com:rust-lang/rust.git',
#       'clone_url': 'https://github.com/rust-lang/rust.git',
#       'svn_url': 'https://github.com/rust-lang/rust',
#       'homepage': 'https://www.rust-lang.org',
#       'size': 474979,
#       'stargazers_count': 40845,
#       'watchers_count': 40845,
#       'language': 'Rust',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 6299,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5242,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 6299,
#       'open_issues': 5242,
#       'watchers': 40845,
#       'default_branch': 'master'}},
#     'base': {'label': 'mvpvg:master',
#      'ref': 'master',
#      'sha': 'fdc0011561c6365c596dfd8fa1ef388162bc89c7',
#      'user': {'login': 'mvpvg',
#       'id': 7826909,
#       'node_id': 'MDQ6VXNlcjc4MjY5MDk=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/7826909?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mvpvg',
#       'html_url': 'https://github.com/mvpvg',
#       'followers_url': 'https://api.github.com/users/mvpvg/followers',
#       'following_url': 'https://api.github.com/users/mvpvg/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mvpvg/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mvpvg/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mvpvg/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mvpvg/orgs',
#       'repos_url': 'https://api.github.com/users/mvpvg/repos',
#       'events_url': 'https://api.github.com/users/mvpvg/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mvpvg/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 203700918,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDM3MDA5MTg=',
#       'name': 'rust',
#       'full_name': 'mvpvg/rust',
#       'private': False,
#       'owner': {'login': 'mvpvg',
#        'id': 7826909,
#        'node_id': 'MDQ6VXNlcjc4MjY5MDk=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/7826909?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/mvpvg',
#        'html_url': 'https://github.com/mvpvg',
#        'followers_url': 'https://api.github.com/users/mvpvg/followers',
#        'following_url': 'https://api.github.com/users/mvpvg/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/mvpvg/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/mvpvg/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/mvpvg/subscriptions',
#        'organizations_url': 'https://api.github.com/users/mvpvg/orgs',
#        'repos_url': 'https://api.github.com/users/mvpvg/repos',
#        'events_url': 'https://api.github.com/users/mvpvg/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/mvpvg/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/mvpvg/rust',
#       'description': 'Empowering everyone to build reliable and efficient software.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/mvpvg/rust',
#       'forks_url': 'https://api.github.com/repos/mvpvg/rust/forks',
#       'keys_url': 'https://api.github.com/repos/mvpvg/rust/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/mvpvg/rust/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/mvpvg/rust/teams',
#       'hooks_url': 'https://api.github.com/repos/mvpvg/rust/hooks',
#       'issue_events_url': 'https://api.github.com/repos/mvpvg/rust/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/mvpvg/rust/events',
#       'assignees_url': 'https://api.github.com/repos/mvpvg/rust/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/mvpvg/rust/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/mvpvg/rust/tags',
#       'blobs_url': 'https://api.github.com/repos/mvpvg/rust/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/mvpvg/rust/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/mvpvg/rust/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/mvpvg/rust/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/mvpvg/rust/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/mvpvg/rust/languages',
#       'stargazers_url': 'https://api.github.com/repos/mvpvg/rust/stargazers',
#       'contributors_url': 'https://api.github.com/repos/mvpvg/rust/contributors',
#       'subscribers_url': 'https://api.github.com/repos/mvpvg/rust/subscribers',
#       'subscription_url': 'https://api.github.com/repos/mvpvg/rust/subscription',
#       'commits_url': 'https://api.github.com/repos/mvpvg/rust/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/mvpvg/rust/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/mvpvg/rust/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/mvpvg/rust/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/mvpvg/rust/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/mvpvg/rust/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/mvpvg/rust/merges',
#       'archive_url': 'https://api.github.com/repos/mvpvg/rust/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/mvpvg/rust/downloads',
#       'issues_url': 'https://api.github.com/repos/mvpvg/rust/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/mvpvg/rust/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/mvpvg/rust/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/mvpvg/rust/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/mvpvg/rust/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/mvpvg/rust/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/mvpvg/rust/deployments',
#       'created_at': '2019-08-22T02:39:35Z',
#       'updated_at': '2019-12-02T18:28:47Z',
#       'pushed_at': '2019-12-02T18:28:41Z',
#       'git_url': 'git://github.com/mvpvg/rust.git',
#       'ssh_url': 'git@github.com:mvpvg/rust.git',
#       'clone_url': 'https://github.com/mvpvg/rust.git',
#       'svn_url': 'https://github.com/mvpvg/rust',
#       'homepage': 'https://www.rust-lang.org',
#       'size': 474744,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Rust',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/mvpvg/rust/pulls/454'},
#      'html': {'href': 'https://github.com/mvpvg/rust/pull/454'},
#      'issue': {'href': 'https://api.github.com/repos/mvpvg/rust/issues/454'},
#      'comments': {'href': 'https://api.github.com/repos/mvpvg/rust/issues/454/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/mvpvg/rust/pulls/454/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/mvpvg/rust/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/mvpvg/rust/pulls/454/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/mvpvg/rust/statuses/4787e97475de6be9487e3d9255a9c2d3c0bf9252'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 8,
#     'additions': 9,
#     'deletions': 8,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z'},
#  {'id': '10996062326',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197735642,
#    'name': 'adeo-gitlab/sync-github-gitlab-19',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-19'},
#   'payload': {'ref': '2019-12-03_05-28-21_851_scenario1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T05:28:35Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '10996062321',
#   'type': 'PushEvent',
#   'actor': {'id': 5544610,
#    'login': 'Dobiasd',
#    'display_login': 'Dobiasd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dobiasd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5544610?'},
#   'repo': {'id': 14185011,
#    'name': 'Dobiasd/articles',
#    'url': 'https://api.github.com/repos/Dobiasd/articles'},
#   'payload': {'push_id': 4347165962,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ad1715a9c8b6ce790b2a169372f53f5a5a6d08b8',
#    'before': 'cb8786f7b2d3199e8753033bf0c968d96144475e',
#    'commits': [{'sha': 'ad1715a9c8b6ce790b2a169372f53f5a5a6d08b8',
#      'author': {'email': 'editgym@gmail.com', 'name': 'Dobiasd'},
#      'message': 'Add pasta logo to refactoring article',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Dobiasd/articles/commits/ad1715a9c8b6ce790b2a169372f53f5a5a6d08b8'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'},
#  {'id': '10996062315',
#   'type': 'PushEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 55580430,
#    'name': 'rx-ts/vue',
#    'url': 'https://api.github.com/repos/rx-ts/vue'},
#   'payload': {'push_id': 4347165960,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/renovate/1stg-stylelint-config-0.x',
#    'head': 'a7dedf46a867b65ede9ff4698b929c2fbd7e8d49',
#    'before': '847a5a5721c9d384a7073b6a57b408e321ed8f81',
#    'commits': [{'sha': 'a7dedf46a867b65ede9ff4698b929c2fbd7e8d49',
#      'author': {'email': 'bot@renovateapp.com', 'name': 'Renovate Bot'},
#      'message': 'chore(deps): update dependency @1stg/stylelint-config',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rx-ts/vue/commits/a7dedf46a867b65ede9ff4698b929c2fbd7e8d49'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z',
#   'org': {'id': 52890036,
#    'login': 'rx-ts',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/rx-ts',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52890036?'}},
#  {'id': '10996062313',
#   'type': 'PushEvent',
#   'actor': {'id': 11022302,
#    'login': 'darinmorrison',
#    'display_login': 'darinmorrison',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/darinmorrison',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11022302?'},
#   'repo': {'id': 221979734,
#    'name': 'interfaces-rs/electron-sys',
#    'url': 'https://api.github.com/repos/interfaces-rs/electron-sys'},
#   'payload': {'push_id': 4347165959,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '4c1acc169fa2050d0eaaf515fb4e4c6cc630ce26',
#    'before': '37904dcf649a0bdf0567e4bc3952f8edeb7732ee',
#    'commits': [{'sha': '4c1acc169fa2050d0eaaf515fb4e4c6cc630ce26',
#      'author': {'email': 'darinmorrison@users.noreply.github.com',
#       'name': 'darinmorrison'},
#      'message': 'Automated deployment: Tue Dec  3 05:28:31 UTC 2019 a53cdfb760c5a763a5c3bf3f31226f10dc6feedd',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/interfaces-rs/electron-sys/commits/4c1acc169fa2050d0eaaf515fb4e4c6cc630ce26'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z',
#   'org': {'id': 57810425,
#    'login': 'interfaces-rs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/interfaces-rs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57810425?'}},
#  {'id': '10996062308',
#   'type': 'CreateEvent',
#   'actor': {'id': 38249713,
#    'login': 'tkdlqm2',
#    'display_login': 'tkdlqm2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tkdlqm2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38249713?'},
#   'repo': {'id': 225537807,
#    'name': 'tkdlqm2/---',
#    'url': 'https://api.github.com/repos/tkdlqm2/---'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'python3를 활용한 문제 풀이',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'},
#  {'id': '10996062298',
#   'type': 'WatchEvent',
#   'actor': {'id': 25096123,
#    'login': 'hamzzy',
#    'display_login': 'hamzzy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hamzzy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25096123?'},
#   'repo': {'id': 225478200,
#    'name': 'staa99/partials.js',
#    'url': 'https://api.github.com/repos/staa99/partials.js'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'},
#  {'id': '10996062292',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 49138417,
#    'name': 'Lombiq/Om.Orchard.SocialMetaTags',
#    'url': 'https://api.github.com/repos/Lombiq/Om.Orchard.SocialMetaTags'},
#   'payload': {'push_id': 4347165947,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/feature/ContentTypeSettings',
#    'head': 'fbd61d301adbc555364bd8ca10ea4898ebb68c2f',
#    'before': 'fbd61d301adbc555364bd8ca10ea4898ebb68c2f',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '10996062290',
#   'type': 'PushEvent',
#   'actor': {'id': 53548787,
#    'login': 'rodemanp',
#    'display_login': 'rodemanp',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rodemanp',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53548787?'},
#   'repo': {'id': 223647710,
#    'name': 'alexisophiek/ETL_Project',
#    'url': 'https://api.github.com/repos/alexisophiek/ETL_Project'},
#   'payload': {'push_id': 4347165950,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '30e6f1311acb2fcbd0c6e5f99e1da9a2d283c720',
#    'before': 'a26cd471eddfe1d241238c0e5ce7a3e43efdaf4a',
#    'commits': [{'sha': '30e6f1311acb2fcbd0c6e5f99e1da9a2d283c720',
#      'author': {'email': '53548787+rodemanp@users.noreply.github.com',
#       'name': 'Patrick V Rodeman'},
#      'message': 'Upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/alexisophiek/ETL_Project/commits/30e6f1311acb2fcbd0c6e5f99e1da9a2d283c720'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'},
#  {'id': '10996062289',
#   'type': 'PushEvent',
#   'actor': {'id': 22896690,
#    'login': 'zhandos38',
#    'display_login': 'zhandos38',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhandos38',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22896690?'},
#   'repo': {'id': 215996571,
#    'name': 'zhandos38/cash-client',
#    'url': 'https://api.github.com/repos/zhandos38/cash-client'},
#   'payload': {'push_id': 4347165946,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ed0f3eaa71d87ebf67d5c7ba6e2638293799f36e',
#    'before': '33e17cb200ab4049b9e2dd29d2a67e1eafe6cf6e',
#    'commits': [{'sha': 'ed0f3eaa71d87ebf67d5c7ba6e2638293799f36e',
#      'author': {'email': 'zhandos38@gmail.com', 'name': 'zhandos38'},
#      'message': 'Added notice about token and in login form rememberme is deleted',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zhandos38/cash-client/commits/ed0f3eaa71d87ebf67d5c7ba6e2638293799f36e'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'},
#  {'id': '10996062282',
#   'type': 'PushEvent',
#   'actor': {'id': 48848312,
#    'login': 'RetaxMaster',
#    'display_login': 'RetaxMaster',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/RetaxMaster',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48848312?'},
#   'repo': {'id': 224318940,
#    'name': 'RetaxMaster/SchoolMedia',
#    'url': 'https://api.github.com/repos/RetaxMaster/SchoolMedia'},
#   'payload': {'push_id': 4347165939,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '307c76e5c3fc00f20f272b8fca5c99fa5a812edd',
#    'before': 'c78b4c62ab86c4aa1932ab40ff60dc28751fa9c3',
#    'commits': [{'sha': '307c76e5c3fc00f20f272b8fca5c99fa5a812edd',
#      'author': {'email': 'retaxmaster@hotmail.com', 'name': 'RetaxMaster'},
#      'message': 'Soncronizacion de cambios',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RetaxMaster/SchoolMedia/commits/307c76e5c3fc00f20f272b8fca5c99fa5a812edd'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'},
#  {'id': '10996062280',
#   'type': 'PushEvent',
#   'actor': {'id': 1012285,
#    'login': 'radzha',
#    'display_login': 'radzha',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/radzha',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1012285?'},
#   'repo': {'id': 158583477,
#    'name': 'radzha/rider',
#    'url': 'https://api.github.com/repos/radzha/rider'},
#   'payload': {'push_id': 4347165941,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '86fe4912507293d11a63fce29c3f601fec62c111',
#    'before': 'd1bc8f1ecfeefda2bd39710611f853940282041b',
#    'commits': [{'sha': '86fe4912507293d11a63fce29c3f601fec62c111',
#      'author': {'email': 'login4pass@gmail.com', 'name': 'radzha'},
#      'message': 'RD-2019.2.3 <d.rakhmatullin@macbook Update vim_settings.xml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/radzha/rider/commits/86fe4912507293d11a63fce29c3f601fec62c111'}]},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'},
#  {'id': '10996062281',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 210660520,
#    'name': 'denisov1985/engine',
#    'url': 'https://api.github.com/repos/denisov1985/engine'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/denisov1985/engine/pulls/1',
#     'id': 348129522,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4MTI5NTIy',
#     'html_url': 'https://github.com/denisov1985/engine/pull/1',
#     'diff_url': 'https://github.com/denisov1985/engine/pull/1.diff',
#     'patch_url': 'https://github.com/denisov1985/engine/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/denisov1985/engine/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump symfony/http-foundation from 4.3.4 to 4.4.1',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [symfony/http-foundation](https://github.com/symfony/http-foundation) from 4.3.4 to 4.4.1.\n<details>\n<summary>Changelog</summary>\n\n*Sourced from [symfony/http-foundation\'s changelog](https://github.com/symfony/http-foundation/blob/master/CHANGELOG.md).*\n\n> CHANGELOG\n> =========\n> \n> 5.0.0\n> -----\n> \n>  * made `Cookie` auto-secure and lax by default\n>  * removed classes in the `MimeType` namespace, use the Symfony Mime component instead\n>  * removed method `UploadedFile::getClientSize()` and the related constructor argument\n>  * made `Request::getSession()` throw if the session has not been set before\n>  * removed `Response::HTTP_RESERVED_FOR_WEBDAV_ADVANCED_COLLECTIONS_EXPIRED_PROPOSAL`\n>  * passing a null url when instantiating a `RedirectResponse` is not allowed\n> \n> 4.4.0\n> -----\n> \n>  * passing arguments to `Request::isMethodSafe()` is deprecated.\n>  * `ApacheRequest` is deprecated, use the `Request` class instead.\n>  * passing a third argument to `HeaderBag::get()` is deprecated, use method `all()` instead\n>  * [BC BREAK] `PdoSessionHandler` with MySQL changed the type of the lifetime column,\n>    make sure to run `ALTER TABLE sessions MODIFY sess_lifetime INTEGER UNSIGNED NOT NULL` to\n>    update your database.\n>  * `PdoSessionHandler` now precalculates the expiry timestamp in the lifetime column,\n>     make sure to run `CREATE INDEX EXPIRY ON sessions (sess_lifetime)` to update your database\n>     to speed up garbage collection of expired sessions.\n>  * added `SessionHandlerFactory` to create session handlers with a DSN\n>  * added `IpUtils::anonymize()` to help with GDPR compliance.\n> \n> 4.3.0\n> -----\n> \n>  * added PHPUnit constraints: `RequestAttributeValueSame`, `ResponseCookieValueSame`, `ResponseHasCookie`,\n>    `ResponseHasHeader`, `ResponseHeaderSame`, `ResponseIsRedirected`, `ResponseIsSuccessful`, and `ResponseStatusCodeSame`\n>  * deprecated `MimeTypeGuesserInterface` and `ExtensionGuesserInterface` in favor of `Symfony\\Component\\Mime\\MimeTypesInterface`.\n>  * deprecated `MimeType` and `MimeTypeExtensionGuesser` in favor of `Symfony\\Component\\Mime\\MimeTypes`.\n>  * deprecated `FileBinaryMimeTypeGuesser` in favor of `Symfony\\Component\\Mime\\FileBinaryMimeTypeGuesser`.\n>  * deprecated `FileinfoMimeTypeGuesser` in favor of `Symfony\\Component\\Mime\\FileinfoMimeTypeGuesser`.\n>  * added `UrlHelper` that allows to get an absolute URL and a relative path for a given path\n> \n> 4.2.0\n> -----\n> \n>  * the default value of the "$secure" and "$samesite" arguments of Cookie\'s constructor\n>    will respectively change from "false" to "null" and from "null" to "lax" in Symfony\n>    5.0, you should define their values explicitly or use "Cookie::create()" instead.\n>  * added `matchPort()` in RequestMatcher\n> \n> 4.1.3\n> -----\n> \n></tr></table> ... (truncated)\n</details>\n<details>\n<summary>Commits</summary>\n\n- [`8bccc59`](https://github.com/symfony/http-foundation/commit/8bccc59e61b41963d14c3dbdb23181e5c932a1d5) Merge branch \'4.3\' into 4.4\n- [`fcafc7c`](https://github.com/symfony/http-foundation/commit/fcafc7c53784919e4bbcb6d5df73cabbb5c39e76) Merge branch \'3.4\' into 4.3\n- [`d2d0cfe`](https://github.com/symfony/http-foundation/commit/d2d0cfe8e319d9df44c4cca570710fcf221d4593) [HttpFoundation] Fixed typo\n- [`cc09809`](https://github.com/symfony/http-foundation/commit/cc09809aa4182d5d062cde2c5836c5281f4e96eb) [HttpFoundation] Update CHANGELOG for PdoSessionHandler BC BREAK in 4.4\n- [`c2480b7`](https://github.com/symfony/http-foundation/commit/c2480b72a0bbf21cb04cd2ea6ef21b9d6b533a45) Merge branch \'3.4\' into 4.3\n- [`f7efd0b`](https://github.com/symfony/http-foundation/commit/f7efd0b387b7bdbfe0fd1e38fe6b7d4a812b4e39) Simpler example for Apache basic auth workaround\n- [`502040d`](https://github.com/symfony/http-foundation/commit/502040dd2b0cf0a292defeb6145f4d7a4753c99c) Merge branch \'4.3\' into 4.4\n- [`0ac9ebf`](https://github.com/symf ...
#     'created_at': '2019-12-03T05:28:33Z',
#     'updated_at': '2019-12-03T05:28:33Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/denisov1985/engine/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/denisov1985/engine/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/denisov1985/engine/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/denisov1985/engine/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/denisov1985/engine/statuses/a9a0cdb3fc82bf25a055d778365a21bda223710f',
#     'head': {'label': 'denisov1985:dependabot/composer/symfony/http-foundation-4.4.1',
#      'ref': 'dependabot/composer/symfony/http-foundation-4.4.1',
#      'sha': 'a9a0cdb3fc82bf25a055d778365a21bda223710f',
#      'user': {'login': 'denisov1985',
#       'id': 3142325,
#       'node_id': 'MDQ6VXNlcjMxNDIzMjU=',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/3142325?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/denisov1985',
#       'html_url': 'https://github.com/denisov1985',
#       'followers_url': 'https://api.github.com/users/denisov1985/followers',
#       'following_url': 'https://api.github.com/users/denisov1985/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/denisov1985/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/denisov1985/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/denisov1985/subscriptions',
#       'organizations_url': 'https://api.github.com/users/denisov1985/orgs',
#       'repos_url': 'https://api.github.com/users/denisov1985/repos',
#       'events_url': 'https://api.github.com/users/denisov1985/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/denisov1985/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 210660520,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTA2NjA1MjA=',
#       'name': 'engine',
#       'full_name': 'denisov1985/engine',
#       'private': False,
#       'owner': {'login': 'denisov1985',
#        'id': 3142325,
#        'node_id': 'MDQ6VXNlcjMxNDIzMjU=',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/3142325?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/denisov1985',
#        'html_url': 'https://github.com/denisov1985',
#        'followers_url': 'https://api.github.com/users/denisov1985/followers',
#        'following_url': 'https://api.github.com/users/denisov1985/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/denisov1985/gists{/gist_id}',
# ...
#       'id': 56247266,
#       'node_id': 'MDQ6VXNlcjU2MjQ3MjY2',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/56247266?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Kmelmelk',
#       'html_url': 'https://github.com/Kmelmelk',
#       'followers_url': 'https://api.github.com/users/Kmelmelk/followers',
#       'following_url': 'https://api.github.com/users/Kmelmelk/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Kmelmelk/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Kmelmelk/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Kmelmelk/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Kmelmelk/orgs',
#       'repos_url': 'https://api.github.com/users/Kmelmelk/repos',
#       'events_url': 'https://api.github.com/users/Kmelmelk/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Kmelmelk/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 219463159,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTk0NjMxNTk=',
#       'name': 'deep-tube',
#       'full_name': 'Kmelmelk/deep-tube',
#       'private': False,
#       'owner': {'login': 'Kmelmelk',
#        'id': 56247266,
#        'node_id': 'MDQ6VXNlcjU2MjQ3MjY2',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/56247266?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Kmelmelk',
#        'html_url': 'https://github.com/Kmelmelk',
#        'followers_url': 'https://api.github.com/users/Kmelmelk/followers',
#        'following_url': 'https://api.github.com/users/Kmelmelk/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Kmelmelk/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Kmelmelk/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Kmelmelk/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Kmelmelk/orgs',
#        'repos_url': 'https://api.github.com/users/Kmelmelk/repos',
#        'events_url': 'https://api.github.com/users/Kmelmelk/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Kmelmelk/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Kmelmelk/deep-tube',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Kmelmelk/deep-tube',
#       'forks_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/forks',
#       'keys_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/teams',
#       'hooks_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/events',
#       'assignees_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/tags',
#       'blobs_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/languages',
#       'stargazers_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/subscription',
#       'commits_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/merges',
#       'archive_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/downloads',
#       'issues_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Kmelmelk/deep-tube/deployments',
#       'created_at': '2019-11-04T09:26:09Z',
#       'updated_at': '2019-11-04T09:40:51Z',
#       'pushed_at': '2019-12-03T05:28:33Z',
#       'git_url': 'git://github.com/Kmelmelk/deep-tube.git',
#       'ssh_url': 'git@github.com:Kmelmelk/deep-tube.git',
#       'clone_url': 'https://github.com/Kmelmelk/deep-tube.git',
#       'svn_url': 'https://github.com/Kmelmelk/deep-tube',
#       'homepage': None,
#       'size': 37,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Kmelmelk/deep-tube/pulls/1'},
#      'html': {'href': 'https://github.com/Kmelmelk/deep-tube/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/Kmelmelk/deep-tube/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/Kmelmelk/deep-tube/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Kmelmelk/deep-tube/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Kmelmelk/deep-tube/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Kmelmelk/deep-tube/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Kmelmelk/deep-tube/statuses/21a2535638f84584b0bfa5d4e9812953cd2e8d5b'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 104,
#     'deletions': 100,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'},
#  {'id': '10996062271',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46623597,
#    'name': 'Lombiq/Orchard-Security',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Security'},
#   'payload': {'push_id': 4347165933,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.10',
#    'head': 'a217cbee127de83c6e71e6c8dc06cb4f28406893',
#    'before': 'a217cbee127de83c6e71e6c8dc06cb4f28406893',
#    'commits': []},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '10996062268',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 219463159,
#    'name': 'Kmelmelk/deep-tube',
#    'url': 'https://api.github.com/repos/Kmelmelk/deep-tube'},
#   'payload': {'ref': 'dependabot/composer/symfony/security-http-4.3.9',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'},
#  {'id': '10996062259',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 56454020,
#    'login': 'NightIICrawler',
#    'display_login': 'NightIICrawler',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NightIICrawler',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56454020?'},
#   'repo': {'id': 214512690,
#    'name': 'ColdxBreaker/Anaconda',
#    'url': 'https://api.github.com/repos/ColdxBreaker/Anaconda'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/ColdxBreaker/Anaconda/comments/36237967',
#     'html_url': 'https://github.com/ColdxBreaker/Anaconda/commit/9e67575bb07b76f5b8322eea894b7c787188cc87#commitcomment-36237967',
#     'id': 36237967,
#     'node_id': 'MDEzOkNvbW1pdENvbW1lbnQzNjIzNzk2Nw==',
#     'user': {'login': 'NightIICrawler',
#      'id': 56454020,
#      'node_id': 'MDQ6VXNlcjU2NDU0MDIw',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/56454020?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/NightIICrawler',
#      'html_url': 'https://github.com/NightIICrawler',
#      'followers_url': 'https://api.github.com/users/NightIICrawler/followers',
#      'following_url': 'https://api.github.com/users/NightIICrawler/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/NightIICrawler/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/NightIICrawler/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/NightIICrawler/subscriptions',
#      'organizations_url': 'https://api.github.com/users/NightIICrawler/orgs',
#      'repos_url': 'https://api.github.com/users/NightIICrawler/repos',
#      'events_url': 'https://api.github.com/users/NightIICrawler/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/NightIICrawler/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'position': 7,
#     'line': 19,
#     'path': 'Snake.py',
#     'commit_id': '9e67575bb07b76f5b8322eea894b7c787188cc87',
#     'created_at': '2019-12-03T05:28:33Z',
#     'updated_at': '2019-12-03T05:28:33Z',
#     'author_association': 'COLLABORATOR',
#     'body': 'make dx = 1 \r\nby default so that the snake \r\nstarts off moving right'}},
#   'public': True,
#   'created_at': '2019-12-03T05:28:33Z'},
#  {'id': '10996062258',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1291874,
#    'login': 'GinsonRen',
#    'display_login': 'GinsonRen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GinsonRen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1291874?'},
#   'repo': {'id': 66424758,
#    'name': 'GinsonRen/liferay-portal',
#    'url': 'https://api.github.com/repos/GinsonRen/liferay-portal'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/GinsonRen/liferay-portal/issues/550',
#     'repository_url': 'https://api.github.com/repos/GinsonRen/liferay-portal',
#     'labels_url': 'https://api.github.com/repos/GinsonRen/liferay-portal/issues/550/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/GinsonRen/liferay-portal/issues/550/comments',
#     'events_url': 'https://api.github.com/repos/GinsonRen/liferay-portal/issues/550/events',
#     'html_url': 'https://github.com/GinsonRen/liferay-portal/pull/550',
#     'id': 531624806,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ4MDQ2NTE1',
#     'number': 550,
#     'title': 'master-qa-54002-1',
#     'user': {'login': 'CatherineWLY',
#      'id': 57254997,
#      'node_id': 'MDQ6VXNlcjU3MjU0OTk3',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/57254997?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/CatherineWLY',
#      'html_url': 'https://github.com/CatherineWLY',
#      'followers_url': 'https://api.github.com/users/CatherineWLY/followers',
#      'following_url': 'https://api.github.com/users/CatherineWLY/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/CatherineWLY/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/CatherineWLY/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/CatherineWLY/subscriptions',
#      'organizations_url': 'https://api.github.com/users/CatherineWLY/orgs',
#      'repos_url': 'https://api.github.com/users/CatherineWLY/repos',
#      'events_url': 'https://api.github.com/users/CatherineWLY/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/CatherineWLY/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-03T00:18:15Z',
#     'updated_at': '2019-12-03T05:28:33Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'pull_request': {'url': 'https://api.github.com/repos/GinsonRen/liferay-portal/pulls/550',
#      'html_url': 'https://github.com/GinsonRen/liferay-portal/pull/550',
#      'diff_url': 'https://github.com/GinsonRen/liferay-portal/pull/550.diff',
#      'patch_url': 'https://github.com/GinsonRen/liferay-portal/pull/550.patch'},
#     'body': 'https://issues.liferay.com/browse/LRQA-54002'},
#    'comment': {'url': 'https://api.github.com/repos/GinsonRen/liferay-portal/issues/comments/561005258',
#     'html_url': 'https://github.com/GinsonRen/liferay-portal/pull/550#issuecomment-561005258',
#     'issue_url': 'https://api.github.com/repos/GinsonRen/liferay-portal/issues/550',
#     'id': 561005258,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDU2MTAwNTI1OA==',
#     'user': {'login': 'GinsonRen',
#      'id': 1291874,
#      'node_id': 'MDQ6VXNlcjEyOTE4NzQ=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/1291874?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/GinsonRen',
#      'html_url': 'https://github.com/GinsonRen',
#      'followers_url': 'https://api.github.com/users/GinsonRen/followers',
#      'following_url': 'https://api.github.com/users/GinsonRen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/GinsonRen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/GinsonRen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/GinsonRen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/GinsonRen/orgs',
#      'repos_url': 'https://api.github.com/users/GinsonRen/repos',
#      'events_url': 'https://api.github.com/users/GinsonRen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/GinsonRen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2019-12-03T05:28:33Z',
#     'updated_at': '2019-12-03T05:28:33Z',
#     'author_association': 'OWNER',
#     'body': 'ci:test:sf'}},
#   'public': True,
#   'created_at': '2019-12-03T05:28:34Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0'},
#  'origin': '140.114.237.23, 140.114.237.23',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.21.0'},
#  'json': None,
#  'origin': '140.114.237.23, 140.114.237.23',
#  'url': 'https://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
